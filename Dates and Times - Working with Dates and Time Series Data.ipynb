# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('/Users/jean110284/Desktop/Everything/MJUPython/ETH_1h.csv')

# %%
df.head(2)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09

# %%
# check more information
# there are 23674 rows and 7 columns

df.shape
# Out:
# (23674, 7)

# %%
# grab the first row date of the dataframe

df.loc[0,'Date']
# Out:
# '2020-03-13 08-PM'

# %%
# error because we are reading this as a string currently

df.loc[0,'Date'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 3>()
#       1 # error because we are reading this as a string currently
# ----> 3 df.loc[0,'Date'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
# use below instead but this will give an error
# as it doesn't know how to parse the date

df['Date']= pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# Input In [15], in <cell line: 4>()
# ...

# %%
df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df['Date']= pd.to_datetime(df['Date'], format = '%Y-%m-%d %I-%p')

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
# it converted the 8pm to 20
# this can be found on python tutorial document

df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
# now if you re-run the previous code
# it already works

df.loc[0,'Date'].day_name()
# Out:
# 'Friday'

# %%
# convert string to time
# lambda x is a row data
# datetime.strptime will convert string to time in a given format
# date column will be the one to be parsed
# date_parser is set to d_parser

d_parser = lambda x: datetime.strptime(x, '%Y-%m-%d %I-%p')
df = pd.read_csv('/Users/jean110284/Desktop/Everything/MJUPython/ETH_1h.csv', parse_dates=['Date'],date_parser=d_parser)

# %%
df.head(5)

# we can see that our dataframe is in datetime type
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
# how to get the day on Date column
df.loc[0,'Date'].day_name()
# Out:
# 'Friday'

# %%
# how to get the format that you want

from datetime import datetime
date = datetime.strptime("2020-01-01 14:00", "%Y-%m-%d %H:%M")
datetime.strftime(date, "%a %B %d, %Y %I:%M %p")
# Out:
# 'Wed January 01, 2020 02:00 PM'

# %%
# how to extract year, month and date from a datetime format
# first thing that you need to do is to check the type of data present on the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23674 entries, 0 to 23673
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    23674 non-null  datetime64[ns]
#  1   Symbol  23674 non-null  object
#  2   Open    23674 non-null  float64
#  3   High    23674 non-null  float64
#  4   Low     23674 non-null  float64
#  5   Close   23674 non-null  float64
#  6   Volume  23674 non-null  float64
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 1.3+ MB

# %%
# we can see that the date is in datetime format already
# incase it is in object, convert it to datetime

df['Date'] = pd.to_datetime(df['Date'])
df['Date']

# now it is re-converted
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
year = df['Date'].dt.year
year
# Out:
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020
#          ...
# 23669    2017
# 23670    2017
# 23671    2017
# 23672    2017
# 23673    2017
# Name: Date, Length: 23674, dtype: int64

# %%
month = df['Date'].dt.month
month
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3
#         ..
# 23669    7
# 23670    7
# 23671    7
# 23672    7
# 23673    7
# Name: Date, Length: 23674, dtype: int64

# %%
day = df['Date'].dt.day
day
# Out:
# 0        13
# 1        13
# 2        13
# 3        13
# 4        13
#          ..
# 23669     1
# 23670     1
# 23671     1
# 23672     1
# 23673     1
# Name: Date, Length: 23674, dtype: int64

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
# add the year column

df['year'] = df['Date'].dt.year
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#        year
# 0      2020
# ...

# %%
df['month'] = df['Date'].dt.month
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#        year  month
# ...

# %%
df['day'] = df['Date'].dt.day
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#        year  month  day
# ...

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#        year  month  day
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23674 entries, 0 to 23673
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    23674 non-null  datetime64[ns]
#  1   Symbol  23674 non-null  object
#  2   Open    23674 non-null  float64
#  3   High    23674 non-null  float64
#  4   Low     23674 non-null  float64
#  5   Close   23674 non-null  float64
#  6   Volume  23674 non-null  float64
#  7   year    23674 non-null  int64
#  8   month   23674 non-null  int64
#  9   day     23674 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(3), object(1)
# memory usage: 1.8+ MB

# %%
# get the year and month

cols=["year","month"]
df['MonthYear'] = df[cols].apply(lambda x: '-'.join(x.values.astype(str)), axis="columns")
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# ...

# %%
# convert to datetime

df['MonthYear']=pd.to_datetime(df['MonthYear'])

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# ...

# %%
df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
# get the day of the week
df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
# create another column

df['DayOfWeek']= df['Date'].dt.day_name()

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# ...

# %%
# there are over 23k rows
# use the min and max method to see the earliest date

df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
# substract or time delta

df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
# view the data for 2020
# create a filter

# filt = (i want our date series that are greater than 2020 )

filt = (df['Date'] >= '2020')
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       year  month  day  MonthYear  DayOfWeek
# ...

# %%
# data for 2019

filt = (df['Date'] >= '2019') & (df['Date'] < '2020')
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
# ...

# %%
filt = (df['Date']>= pd.to_datetime('2019-01-01')) & (df['Date'] < pd.to_datetime('2020-01-01'))
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
# ...

# %%
# set date as index
df.set_index('Date')
# Out:
#                      Symbol    Open    High     Low   Close      Volume  year  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93  2020
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09  2020
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81  2020
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92  2020
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71  2020
# ...                     ...     ...     ...     ...     ...         ...   ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55  2017
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85  2017
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99  2017
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87  2017
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87  2017
#
# ...

# %%
# set date as index, make it permanent
df.set_index('Date', inplace = True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  year  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93  2020
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09  2020
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81  2020
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92  2020
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71  2020
# ...                     ...     ...     ...     ...     ...         ...   ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55  2017
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85  2017
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99  2017
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87  2017
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87  2017
#
# ...

# %%
df['2019']
# Out:
# /var/folders/_c/7_nlp2l53sbcnpz463hcc70w0000gn/T/ipykernel_3277/1813439174.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2019']
#                      Symbol    Open    High     Low   Close      Volume  year  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91  2019
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02  2019
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69  2019
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38  2019
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84  2019
# ...                     ...     ...     ...     ...     ...         ...   ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37  2019
# ...

# %%
# all of the data from jan - to feb of 2020

df['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  year  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88  2020
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57  2020
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03  2020
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65  2020
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20  2020
# ...                     ...     ...     ...     ...     ...         ...   ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82  2020
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23  2020
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72  2020
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40  2020
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91  2020
#
# ...

# %%
# get the average closing price of eth
# first get the values on close column

df['2020-01':'2020-02']['Close']
# Out:
# Date
# 2020-02-29 23:00:00    217.31
# 2020-02-29 22:00:00    223.35
# 2020-02-29 21:00:00    223.48
# 2020-02-29 20:00:00    224.63
# 2020-02-29 19:00:00    225.31
#                         ...
# 2020-01-01 04:00:00    129.56
# 2020-01-01 03:00:00    129.57
# 2020-01-01 02:00:00    130.37
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.34
# Name: Close, Length: 1440, dtype: float64

# %%
df['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.16559027777814

# %%
# what if we wanted to look it in a daily basis?
# view the highs for each day

df['2020-01':'2020-02'].head(24)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  year  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88  2020
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57  2020
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03  2020
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65  2020
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20  2020
# 2020-02-29 18:00:00  ETHUSD  225.53  226.17  224.50  225.09   496543.91  2020
# 2020-02-29 17:00:00  ETHUSD  222.68  225.53  222.24  225.53   611136.47  2020
# 2020-02-29 16:00:00  ETHUSD  224.17  225.93  222.36  222.68   694384.75  2020
# 2020-02-29 15:00:00  ETHUSD  223.35  225.88  221.80  224.17   550893.74  2020
# 2020-02-29 14:00:00  ETHUSD  224.42  224.42  221.15  223.35  1479928.44  2020
# 2020-02-29 13:00:00  ETHUSD  225.29  225.37  222.87  224.42  1076646.41  2020
# ...

# %%
# what is the high value for the day of jan 1?
df['2020-01-01']['High']
# Out:
# /var/folders/_c/7_nlp2l53sbcnpz463hcc70w0000gn/T/ipykernel_3277/2346637260.py:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2020-01-01']['High']
# Date
# 2020-01-01 23:00:00    130.27
# 2020-01-01 22:00:00    131.41
# 2020-01-01 21:00:00    131.99
# 2020-01-01 20:00:00    131.87
# 2020-01-01 19:00:00    131.72
# 2020-01-01 18:00:00    132.14
# 2020-01-01 17:00:00    132.68
# 2020-01-01 16:00:00    132.56
# 2020-01-01 15:00:00    132.15
# 2020-01-01 14:00:00    132.05
# 2020-01-01 13:00:00    132.08
# 2020-01-01 12:00:00    131.31
# 2020-01-01 11:00:00    131.42
# 2020-01-01 10:00:00    130.33
# 2020-01-01 09:00:00    130.22
# 2020-01-01 08:00:00    130.01
# 2020-01-01 07:00:00    130.25
# 2020-01-01 06:00:00    130.25
# 2020-01-01 05:00:00    129.94
# 2020-01-01 04:00:00    130.00
# ...

# %%
df['2020-01-01']['High'].max()
# Out:
# /var/folders/_c/7_nlp2l53sbcnpz463hcc70w0000gn/T/ipykernel_3277/3485283041.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2020-01-01']['High'].max()
# 132.68

# %%
# view by day
# do this by resampling
#df['High'].resample('how we want to resample the data, we want it by day or 'D').(what do we want to do with this resampling)

df['High'].resample('D').max()
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
conda update ipython
# Out:
# ...
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::babel==2.9.1=pyhd3eb1b0_0
#   - defaults/osx-64::tqdm==4.64.0=py39hecd8cb5_0
#   - defaults/noarch::conda-pack==0.6.0=pyhd3eb1b0_0
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/noarch::python-slugify==5.0.2=pyhd3eb1b0_0
#   - defaults/osx-64::scikit-learn==1.0.2=py39hae1ba45_1
#   - defaults/noarch::arrow==1.2.2=pyhd3eb1b0_0
#   - defaults/noarch::xmltodict==0.12.0=pyhd3eb1b0_0
#   - defaults/osx-64::mpmath==1.2.1=py39hecd8cb5_0
#   - defaults/noarch::ptyprocess==0.7.0=pyhd3eb1b0_2
#   - defaults/noarch::jupyterlab_widgets==1.0.0=pyhd3eb1b0_1
#   - defaults/noarch::yapf==0.31.0=pyhd3eb1b0_0
#   - defaults/noarch::pkginfo==1.8.2=pyhd3eb1b0_0
#   - defaults/noarch::poyo==0.5.0=pyhd3eb1b0_0
#   - defaults/osx-64::mkl-service==2.4.0=py39h9ed2024_0
# ...

# %%
# below is equal to above
highs = df['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.68

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib

# %%
# %matplotlib inline

# %%
# plot

highs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# what if we want to resample it by day
# together with other data
# resample it by week or 'W'

df.resample('W').mean()
# Out:
#                   Open        High         Low       Close        Volume  \
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
#               year     month        day
# Date
# ...

# %%
#df.resample('W').agg({dictionary of column names and values will be the aggregation
                    # functions})
# get the mean, max, min and sum for each column

df.resample('W').agg({'Close':'mean',
                     'High': 'max',
                     'Low': 'min',
                     'Volume':'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]
